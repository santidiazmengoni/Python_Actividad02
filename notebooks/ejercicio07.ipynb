# %%
import sys
sys.path.append('../src')

# %%
import amigoinvisible

# %%
import importlib
importlib.reload(amigoinvisible)
# Out:
# <module 'amigoinvisible' from 'c:\\Users\\User\\Documents\\Repositorios\\Python_Actividad02\\notebooks\\../src\\amigoinvisible.py'>

# %%
nombres = input("Ingrese los nombres de los participantes (separados por coma): ")
participantes = amigoinvisible.lista_participantes(nombres)

# %%
if not amigoinvisible.validacion_participantes(participantes):
    print("Lista de nombres no válida, hay nombre repetido")
else:
    resultado = amigoinvisible.sorteo_amigo(participantes)

    print("\nSorteo de amigo invisible: ")
    for persona in resultado:
        print(f"{persona} -> {resultado[persona]}")
# Out:
# Sorteo de amigo invisible:
# Ana -> Mateo
# Pedro -> Ana
# Lucia -> Pedro
# Mateo -> Sofia
# Sofia -> Lucia
