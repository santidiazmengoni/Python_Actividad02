# %%
import sys
sys.path.append('../src')

# %%
import envio

# %%
import importlib
importlib.reload(envio)
# Out:
# <module 'envio' from 'c:\\Users\\User\\Documents\\Repositorios\\Python_Actividad02\\notebooks\\../src\\envio.py'>

# %%
peso = float(input("Ingrese peso del paquete en kg: "))
zona = input("Ingrese zona (local, regional, nacional)")

# %%
costo = envio.costo_envio(peso,zona)

if costo == -1:
    print("Zona no valida. Las zonas disponibles son: local, regional, nacional")
else:
    print(f"Costo del envio: {costo}")
# Out:
# Costo del envio: 2000
