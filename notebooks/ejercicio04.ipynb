# %%
import sys
sys.path.append('../src')

# %%
import validacion

# %%
import importlib
importlib.reload(validacion)
# Out:
# <module 'validacion' from 'c:\\Users\\User\\Documents\\Repositorios\\Python_Actividad02\\notebooks\\../src\\validacion.py'>

# %%
email = input("Ingresa un email: ")

# %%
if(validacion.validacion_email(email)):
    print("Email valido")
else:
    print("Email invalido")
# Out:
# Email invalido
