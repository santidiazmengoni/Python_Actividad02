# %%
playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

# %%
import sys
sys.path.append('../src')

# %%
import duracion

# %%
import importlib
importlib.reload(duracion)
# Out:
# <module 'duracion' from 'c:\\Users\\User\\Documents\\Repositorios\\Python_Actividad02\\notebooks\\../src\\duracion.py'>

# %%
duracion.duracion_total(playlist)
# Out:
# 46m 53s

# %%
duracion.cancion_larga(playlist)
# Out:
# {'title': 'Stairway to Heaven', 'duration': '8:02'}

# %%
duracion.cancion_corta(playlist)
# Out:
# {'title': 'Imagine', 'duration': '3:07'}
